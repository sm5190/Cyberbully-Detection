# %%
# !pip install snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
# Creating list to append tweet data to
tweets_list_BD= []
tweets_list2 = []

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(' covid near:"Bangladesh" since:2020-01-01 until:2020-03-31 lang:en').get_items()):
    tweets_list2.append([tweet.date, tweet.content])
    
# Creating a dataframe from the tweets list above

# %%
tweets_df = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text'])
tweets_df.to_csv('2020_BD_mar_jan.csv')

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list_ocd, columns=['Datetime', 'Text'])
tweets_df2.to_csv('ocd_usa.csv')

# %%
# !pip install twint
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 263 kB 70.8 MB/s
# ...
#      |████████████████████████████████| 385 kB 53.6 MB/s
# ...
#      |████████████████████████████████| 291 kB 55.7 MB/s
# ...
#      |████████████████████████████████| 192 kB 64.8 MB/s
# ...
#      |████████████████████████████████| 160 kB 51.1 MB/s
# ...
#      |████████████████████████████████| 271 kB 63.0 MB/s
# ...
#      |████████████████████████████████| 49 kB 6.6 MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.20-py3-none-any.whl size=33930 sha256=b2fbc1b95c07a9eda46a31aac56f75d0cfb0e8eb024ec63f3e1356bd55728a4c
#   Stored in directory: /root/.cache/pip/wheels/44/fc/77/99887a36b5c265a87516158858697d1a0b8f32c4d4dbddbb24
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=87d1f7fb1641f348566aae1943de74fef5d22547c2aeb372baef870f46088554
# ...

# %%
import nest_asyncio
nest_asyncio.apply()
__import__('IPython').embed()
# Out:
# Python 3.7.12 (default, Sep 10 2021, 00:21:48)
# Type "copyright", "credits" or "license" for more information.
#
# IPython 5.5.0 -- An enhanced Interactive Python.
# ?         -> Introduction and overview of IPython's features.
# %quickref -> Quick reference.
# help      -> Python's own help system.
# object?   -> Details about 'object', use 'object??' for extra details.
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 1.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 8.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 27.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 64.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 125.0 secs
# ...

# %%
import twint

c = twint.Config()

c.Search = ['#Indianeedsoxygen']       # topic
c.Limit = 500      # number of Tweets to scrape
c.Store_csv = True       # store tweets in a csv file
c.Output = "India_oxygen.csv"     # path to csv file

# %%
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-f28f8e9aab1e> in <module>()
# ----> 1 twint.run.Search(c)
#
# /usr/local/lib/python3.7/dist-packages/twint/run.py in Search(config, callback)
#     325     config.Profile = False
#     326     config.Profile_full = False
# --> 327     run(config, callback)
#     328     if config.Pandas_au:
#     329         storage.panda._autoget("tweet")
#
# /usr/local/lib/python3.7/dist-packages/twint/run.py in run(config, callback)
#     224         raise
#     225
# --> 226     get_event_loop().run_until_complete(Twint(config).main(callback))
#     227
#     228 def Favorites(config):
#
# /usr/lib/python3.7/asyncio/base_events.py in run_until_complete(self, future)
#     561         """
#     562         self._check_closed()
# --> 563         self._check_runnung()
#     564
# ...

# %%
#!pip install GetOldTweets3
import GetOldTweets3 as got
import numpy
import pandas as pd

# %%
text_query = 'USA Election 2020'
since_date = '2010-01-01'
until_date = '2019-10-31'
count = 2000# Creation of query object
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setSince(since_date).setUntil(until_date).setMaxTweets(count)# Creation of list that contains all tweets

# %%
# !pip install -q snscrape==0.3.4

# %%
import snscrape.modules.twitter as sntwitter
import pandas

tweets_list1 = []

for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"t20wordcup"   since:2020-01-01 until:2022-01-01').get_items()):
    if i>10000:
        break
    tweets_list1.append([tweet.date, tweet.content])
   
USA_Election = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text'])
# Out:
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-9-ea3cc8659920> in <module>()
#       4 tweets_list1 = []
#       5
# ----> 6 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"t20wordcup"   since:2020-01-01 until:2022-01-01').get_items()):
#       7     if i>10000:
#       8         break
#
# /usr/local/lib/python3.7/dist-packages/snscrape/modules/twitter.py in get_items(self)
#     129                 while True:
#     130                         if not guestToken:
# --> 131                                 guestToken = self._get_guest_token()
#     132                                 self._session.cookies.set('gt', guestToken, domain = '.twitter.com', path = '/', secure = True, expires = time.time() + 10800)
#     133                                 headers['x-guest-token'] = guestToken
#
# ...

# %%
USA_Election = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text'])

# %%
tweets = got.manager.TweetManager.getTweets(tweetCriteria)# Creating list of chosen tweet data
# Out:
# An error occured during an HTTP request: HTTP Error 404: Not Found
# Try to open in browser: https://twitter.com/search?q=USA%20Election%202020%20since%3A2010-01-01%20until%3A2019-10-31&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# install Anaconda3
# !wget -qO ac.sh https://repo.anaconda.com/archive/Anaconda3-2020.07-Linux-x86_64.sh 
# !bash ./ac.sh -b

# a fake google.colab library
# !ln -s /usr/local/lib/python3.7/dist-packages/google \
       /root/anaconda3/lib/python3.8/site-packages/google

# start jupyterlab, which now has Python3 = 3.8
# !nohup /root/anaconda3/bin/jupyter-lab --ip=0.0.0.0&

# access through ngrok, click the link
# !pip install pyngrok -q
from pyngrok import ngrok
print(ngrok.connect(8888))
# Out:
# ERROR: File or directory already exists: '/root/anaconda3'
# If you want to update an existing installation, use the -u option.
# ln: failed to create symbolic link '/root/anaconda3/lib/python3.8/site-packages/google/google': File exists
# nohup: appending output to 'nohup.out'
# t=2022-01-03T14:23:34+0000 lvl=warn msg="failed to start tunnel" pg=/api/tunnels id=b63cea7c4fd53ddc err="Your account may not run more than 2 tunnels over a single ngrok client session.\nThe tunnels already running on this session are:\ntn_23BqBw9cnuE0tHzaGQIWeDwDs7Z, tn_23BqByDCK7hvVFSd0zsKX4JL6Jl\n\r\n\r\nERR_NGROK_324\r\n"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout)
#     439     try:
# --> 440         response = urlopen(request, data, timeout)
# ...

# %%
import snscrape.modules.twitter as sntwitter
import csv
csvFile = open('place_result.csv', 'a', newline='', encoding='utf8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['id','date','tweet',]) 
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:@username + since:2009-01-01 until:2020-11-05 -filter:links -filter:replies').get_items()):
    csvWriter.writerow([tweet.id, tweet.date, tweet.content])
csvFile.close()
# Out:
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-17-997c1c6ebf78> in <module>()
#       4 csvWriter = csv.writer(csvFile)
#       5 csvWriter.writerow(['id','date','tweet',])
# ----> 6 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:@username + since:2009-01-01 until:2020-11-05 -filter:links -filter:replies').get_items()):
#       7     csvWriter.writerow([tweet.id, tweet.date, tweet.content])
#       8 csvFile.close()
#
# /usr/local/lib/python3.7/dist-packages/snscrape/modules/twitter.py in get_items(self)
#     129                 while True:
#     130                         if not guestToken:
# --> 131                                 guestToken = self._get_guest_token()
#     132                                 self._session.cookies.set('gt', guestToken, domain = '.twitter.com', path = '/', secure = True, expires = time.time() + 10800)
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('USA Election  near:"USA" since:2020-01-01 until:2021-12-31').get_items()):
    tweets_list2.append([tweet.date, tweet.content])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text'])
tweets_df2.to_csv('USA_ELECTION.csv')
# Out:
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-14-a22d3d078d00> in <module>()
#       6
#       7 # Using TwitterSearchScraper to scrape data and append tweets to list
# ----> 8 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('USA Election  near:"USA" since:2020-01-01 until:2021-12-31').get_items()):
#       9     tweets_list2.append([tweet.date, tweet.content])
#      10
#
# /usr/local/lib/python3.7/dist-packages/snscrape/modules/twitter.py in get_items(self)
#     129                 while True:
#     130                         if not guestToken:
# --> 131                                 guestToken = self._get_guest_token()
#     132                                 self._session.cookies.set('gt', guestToken, domain = '.twitter.com', path = '/', secure = True, expires = time.time() + 10800)
# ...

# %%
# !pip install snscrape
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('RAPE near:"Bangladesh" since:2020-07-01 until:2020-12-31').get_items()):
    if i>100:
        break
    tweets_list2.append([tweet.date, tweet.content])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text'])
tweets_df2.to_csv('COVID-19_usa.csv')
# Out:
# ...
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-15-d99b29835801> in <module>()
#       7
#       8 # Using TwitterSearchScraper to scrape data and append tweets to list
# ----> 9 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('RAPE near:"Bangladesh" since:2020-07-01 until:2020-12-31').get_items()):
#      10     if i>100:
#      11         break
#
# /usr/local/lib/python3.7/dist-packages/snscrape/modules/twitter.py in get_items(self)
#     129                 while True:
#     130                         if not guestToken:
# --> 131                                 guestToken = self._get_guest_token()
#     132                                 self._session.cookies.set('gt', guestToken, domain = '.twitter.com', path = '/', secure = True, expires = time.time() + 10800)
#     133                                 headers['x-guest-token'] = guestToken
#
# ...
